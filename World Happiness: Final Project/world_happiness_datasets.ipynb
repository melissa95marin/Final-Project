# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
happiness = pd.read_csv ('world-happiness-report.2005-2020csv.csv')
happiness
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008         3.72                7.37            0.45
# 1     Afghanistan  2009         4.40                7.54            0.55
# 2     Afghanistan  2010         4.76                7.65            0.54
# 3     Afghanistan  2011         3.83                7.62            0.52
# 4     Afghanistan  2012         3.78                7.71            0.52
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016         3.73                7.98            0.77
# 1945     Zimbabwe  2017         3.64                8.02            0.75
# 1946     Zimbabwe  2018         3.62                8.05            0.78
# 1947     Zimbabwe  2019         2.69                7.95            0.76
# 1948     Zimbabwe  2020         3.16                7.83            0.72
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
happiness.describe()
# Out:
#           year  Life Ladder  Log GDP per capita  Social support  \
# count  1949.00      1949.00             1913.00         1936.00
# mean   2013.22         5.47                9.37            0.81
# std       4.17         1.12                1.15            0.12
# min    2005.00         2.38                6.63            0.29
# 25%    2010.00         4.64                8.46            0.75
# 50%    2013.00         5.39                9.46            0.84
# 75%    2017.00         6.28               10.35            0.91
# max    2020.00         8.02               11.65            0.99
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                           1894.00                       1917.00
# mean                              63.36                          0.74
# std                                7.51                          0.14
# min                               32.30                          0.26
# ...

# %%
happiness.shape
# Out:
# (1949, 11)

# %%
pd.set_option("display.precision", 2)
happiness.head
# Out:
# <bound method NDFrame.head of      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008         3.72                7.37            0.45
# 1     Afghanistan  2009         4.40                7.54            0.55
# 2     Afghanistan  2010         4.76                7.65            0.54
# 3     Afghanistan  2011         3.83                7.62            0.52
# 4     Afghanistan  2012         3.78                7.71            0.52
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016         3.73                7.98            0.77
# 1945     Zimbabwe  2017         3.64                8.02            0.75
# 1946     Zimbabwe  2018         3.62                8.05            0.78
# 1947     Zimbabwe  2019         2.69                7.95            0.76
# 1948     Zimbabwe  2020         3.16                7.83            0.72
#
# ...

# %%
print(df['Country name'])
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1944       Zimbabwe
# 1945       Zimbabwe
# 1946       Zimbabwe
# 1947       Zimbabwe
# 1948       Zimbabwe
# Name: Country name, Length: 1949, dtype: object

# %%
df["Country name"].value_counts().sort_values(ascending = False)
# Out:
# Zimbabwe       15
# Russia         15
# Philippines    15
# Mexico         15
# Moldova        15
#                ..
# Maldives        1
# Suriname        1
# Cuba            1
# Oman            1
# Guyana          1
# Name: Country name, Length: 166, dtype: int64

# %%
print(f"The number of countries in our dataset is: {df['Country name'].nunique()}")
# Out:
# The number of countries in our dataset is: 166

# %%
df['year'].value_counts()
# Out:
# 2017    147
# 2011    146
# 2014    145
# 2019    144
# 2015    143
# 2012    142
# 2016    142
# 2018    142
# 2013    137
# 2010    124
# 2009    114
# 2008    110
# 2007    102
# 2020     95
# 2006     89
# 2005     27
# Name: year, dtype: int64

# %%
df['Country name','year']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Country name', 'year')
#
# The above exception was the direct cause of the following exception:
#
# ...
